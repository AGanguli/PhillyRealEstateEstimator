# %% [markdown]
# # Philadelphia Real Estate Building Profitability

# %% [markdown]
# Hello world

# %% [markdown]
# rtt_summary data comes from: https://data.phila.gov/visualizations/real-estate-transfers
#
# pa_properties_publick comes from: https://opendataphilly.org/datasets/philadelphia-properties-and-assessment-history/

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
transfers = pd.read_csv(
    'rtt_summary.csv', 
    parse_dates=['display_date', 'document_date'],
    usecols=[
        'document_type', 'display_date', 'street_address', 
        'zip_code', 'cash_consideration', 'other_consideration', 
        'total_consideration', 'assessed_value', 'fair_market_value',
        'reg_map_id', 'matched_regmap', 'property_count',
        'shape', 'document_date', 'condo_name', 'record_id',
        'unit_num', 'address_low', 'address_low_suffix', 'address_low_frac', 'address_high',
        'street_name', 'street_suffix', 'street_postdir'
    ],
    dtype={
        'document_type': str,
        'street_address': str,
        'zip_code': 'string',
        'cash_consideration': 'Float64',
        'other_consideration': 'Float64',
        'total_consideration': 'Float64',
        'assessed_value': 'Float64',
        'fair_market_value': 'Float64',
        'reg_map_id': str,
        'matched_regmap': str,
        'property_count': 'Int32',
        'record_id': 'Int64',
        'unit_num': 'string',
        'shape': 'string',
        'address_low': 'string',
        'address_low_suffix': 'string',
        'address_low_frac': 'string',
        'address_high': 'string',
        'street_name': 'string',
        'street_suffix': 'string',
        'street_postdir': 'string',
        'condo_name': 'string',
        'record_id': 'string'
    }
)

# %%
properties = pd.read_csv(
    'opa_properties_public.csv', 
    parse_dates=['assessment_date','date_exterior_condition','market_value_date','recording_date', 'sale_date'],
    usecols=[
        'objectid', 'basements', 'building_code', 'building_code_description',
        'category_code', 'category_code_description', 'census_tract',
        'central_air','depth', 'exempt_building', 'exempt_land', 'exterior_condition',
        'fireplaces', 'frontage', 'fuel', 'garage_spaces', 'garage_type', 'general_construction',
        'geographic_ward', 'homestead_exemption', 'house_extension', 'house_number',
        'interior_condition', 'location', 'mailing_address_1', 'mailing_address_2', 'mailing_care_of',
        'mailing_city_state', 'mailing_street', 'mailing_zip', 'market_value', 'number_of_bathrooms',
        'number_of_bedrooms', 'number_of_rooms', 'number_stories', 'off_street_open', 'other_building',
        'owner_1', 'owner_2', 'parcel_number', 'parcel_shape', 'quality_grade', 'registry_number',
        'sale_price', 'separate_utilities', 'separate_utilities', 'quality_grade', 'sewer',
        'site_type', 'state_code', 'street_code', 'street_designation', 'street_direction',
        'street_name', 'suffix', 'taxable_building', 'taxable_land', 'topography', 'total_area',
        'total_livable_area', 'type_heater', 'unfinished', 'unit', 'utility', 'view_type',
        'year_built', 'year_built_estimate', 'zip_code', 'zoning', 'pin', 'building_code_new',
        'building_code_description_new', 'shape','assessment_date','date_exterior_condition',
        'market_value_date','recording_date', 'sale_date'
    ],
    dtype={
        'objectid': np.int64,
        'basements': 'string',
        'building_code': 'string',
        'building_code_description': 'string',
        'category_code': 'Int32',
        'category_code_description': 'string',
        'census_tract': 'string',
        'central_air': 'string',
        'depth': 'Float32',
        'exempt_building': 'string',
        'exempt_land': 'string',
        'exterior_condition': 'string',
        'fireplaces': 'Int32',
        'frontage': 'string',
        'fuel': 'string',
        'garage_spaces': 'Int32',
        'garage_type': 'string',
        'general_construction': 'string',
        'geographic_ward': 'string',
        'homestead_exemption': 'string',
        'house_extension': 'string',
        'house_number': 'string',
        'interior_condition': 'string',
        'location': 'string',
        'mailing_address_1': 'string',
        'mailing_address_2': 'string',
        'mailing_care_of': 'string',
        'mailing_city_state': 'string',
        'mailing_street': 'string',
        'mailing_zip': 'string',
        'market_value': 'Float64',
        'number_of_bathrooms': 'Int32',
        'number_of_bedrooms': 'Int32',
        'number_of_rooms': 'Int32',
        'number_stories': 'Int32',
        'off_street_open': 'string',
        'other_building': 'string',
        'owner_1': 'string',
        'owner_2': 'string',
        'parcel_number': 'string',
        'parcel_shape': 'string',
        'quality_grade': 'string',
        'registry_number': 'string',
        'sale_price': 'Float64',
        'separate_utilities': 'string',
        'separate_utilities': 'string',
        'quality_grade': 'string',
        'sewer': 'string',
        'site_type': 'string',
        'state_code': 'string',
        'street_code': 'string',
        'street_designation': 'string',
        'street_direction': 'string',
        'street_name': 'string',
        'suffix': 'string',
        'taxable_building': 'Float32',
        'taxable_land': 'Float32',
        'topography': 'string',
        'total_area': 'Float32',
        'total_livable_area': 'Float32',
        'type_heater': 'string',
        'unfinished': 'string',
        'unit': 'string',
        'utility': 'string',
        'view_type': 'string',
        'year_built': 'Int32',
        'year_built_estimate': 'string',
        'zip_code': 'string',
        'zoning': 'string',
        'pin': 'string',
        'building_code_new': 'string',
        'building_code_description_new': 'string',
        'shape': 'string',
    }
)

# %%
pd.set_option('display.max_columns', None)

# %%
properties.shape
# Out:
# (463626, 76)

# %%
properties = properties[properties['category_code'] == 1]
properties.shape
# Out:
# (463626, 76)

# %%
transfers.shape
# Out:
# (4637041, 24)

# %%
transfers = transfers[transfers['document_type'] == 'DEED']
transfers.shape
# Out:
# (978220, 24)

# %%
properties[(properties['street_name'] == 'FOWLER') & properties['house_number'].str.startswith('6956', na=False)]
# Out:
#          objectid            assessment_date basements building_code  \
# 173757  365132699  2022-05-24 12:13:13-04:00         0         C21
#
#         building_code_description  category_code category_code_description  \
# 173757  DET W/D GAR 1.5 STY MAS+O              1             SINGLE FAMILY
#
#        census_tract central_air date_exterior_condition  depth  \
# 173757          216           N                     NaT  100.0
#
#        exempt_building exempt_land exterior_condition  fireplaces frontage  \
# 173757             0.0         0.0                  4           0     57.0
#
#         fuel  garage_spaces garage_type general_construction geographic_ward  \
# 173757  <NA>              1        <NA>                   H               21
#
#        homestead_exemption house_extension house_number interior_condition  \
# 173757                   0            <NA>        6956                   4
#
#               location mailing_address_1 mailing_address_2 mailing_care_of  \
# ...

# %%
properties[(properties['street_name'] == 'FOWLER') & (properties['house_number'] == '6956')]
# Out:
# Empty DataFrame
# ...

# %%
transfers[transfers['street_name'].str.startswith('6956 FOWLER', na=False)]
# Out:
#           objectid  document_id           document_type  \
# 80997    142512712     50051285                MORTGAGE
# 342633   142782213     50305773                MORTGAGE
# 502876   142944361     50458177  ASSIGNMENT OF MORTGAGE
# 580449   143006694     50517041     RELEASE OF MORTGAGE
# 640827   143077911     50585328     RELEASE OF MORTGAGE
# 640828   143077912     50585329     RELEASE OF MORTGAGE
# 640829   143077913     50585330                MORTGAGE
# 645281   143084261     50591277     RELEASE OF MORTGAGE
# 1748306  144180544     51609445                MORTGAGE
# 1748307  144180545     51609446                MORTGAGE
# 1782543  144203422     51630456     RELEASE OF MORTGAGE
# 2336444  144748865     52129910  ASSIGNMENT OF MORTGAGE
# 3370257  145784856     53069845  ASSIGNMENT OF MORTGAGE
# 3503358  145919732     53192897            SATISFACTION
# 3510300  145907417     53181539  ASSIGNMENT OF MORTGAGE
# 3511431  145911701     53185609     RELEASE OF MORTGAGE
# ...

# %%
transfers
# Out:
#           objectid  document_id document_type               display_date  \
# 0        142431438      2999998          DEED  1986-12-10 05:00:00+00:00
# 1        142431439      2999998          DEED  1986-12-10 05:00:00+00:00
# 2        142431440      2999998          DEED  1986-12-10 05:00:00+00:00
# 3        142431441      2999998          DEED  1986-12-10 05:00:00+00:00
# 4        142431442      2999998          DEED  1986-12-10 05:00:00+00:00
# ...            ...          ...           ...                        ...
# 4637036  147068246     54189675      MORTGAGE  2023-06-12 19:23:08+00:00
# 4637037  147068247     54189676          DEED  2023-05-12 19:39:29+00:00
# 4637038  147068248     54189677          DEED  2023-06-09 04:00:00+00:00
# 4637039  147068249     54189678      MORTGAGE  2023-06-12 19:25:47+00:00
# 4637040  147068250     54189679          DEED  2023-06-09 04:00:00+00:00
#
#                   street_address   zip_code  cash_consideration  \
# ...

# %%
df['document_type'].unique()
# Out:
# array(['DEED', 'MISCELLANEOUS DEED', "SHERIFF'S DEED", 'MORTGAGE',
#        'DEED OF CONDEMNATION', 'SATISFACTION OF MORTGAGE',
#        'ASSIGNMENT OF MORTGAGE', 'RELEASE OF MORTGAGE', nan,
#        'AMENDMENT TO DECLARATION OF CONDOMINIUM',
#        'DECLARATION OF CONDOMINIUM', 'POWER OF ATTORNEY', 'ASSIGNMENT',
#        'TERMINATION', 'AMENDMENT', 'CONTINUATION',
#        'ORIGINAL FINANCING STATEMENT', 'SATISFACTION',
#        'DEED MISCELLANEOUS', 'DEED SHERIFF',
#        'CERTIFICATE OF STOCK TRANSFER', 'DEED MISCELLANEOUS TAXABLE',
#        'MISCELLANEOUS DEED TAXABLE', 'AMENDMENT TO CONDOMINIUM',
#        'AFFIDAVIT OF STREET OPENING',
#        'AMENDMENT TO DECLARATION OF PLANNED COMMUNITY',
#        'DECLARATION OF PLANNED COMMUNITY', 'DM - LIS PENDENS',
#        'DEED LAND BANK', 'NOTARY COMMISSION', 'DEED - DECEASED ',
#        'DEED RTT - OTHER', 'DEED - ADVERSE POSSESSION',
#        'ALL OTHER MISCELLANEOUS INSTRUMENTS',
# ...
